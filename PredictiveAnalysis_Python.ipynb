# %%
#importing necessary packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import spearmanr
import numpy as np

# %%
#importing my dataset
salmon=pd.read_excel('chinook.xlsx')

# %%
#show salmon df
print(salmon)
# Out:
#     Year  Commercial_catch  Recreation_catch  Population_size   Temp  \
# 0   1984            241956            173817            87458  53.04
# 1   1985            245308            128042           113163  51.44
# 2   1986            223960            153426            98334  54.27
# 3   1987            213059            109374            86407  54.72
# 4   1988            231479            115300            94799  53.58
# 5   1989            253888            135696            85001  53.17
# 6   1990            250195            125504           137264  53.73
# 7   1991            141686             90566            57428  53.40
# 8   1992            109827             97733            42355  54.59
# 9   1993             81759             80166            33228  53.17
# 10  1994             86768             48286            41437  54.00
# 11  1995             80124             69799            51640  54.61
# 12  1996             76107             72069            58366  52.74
# ...

# %%
#boxplot for population
salmon.boxplot(column='Population_size')

#describe stats for population
salmon.Population_size.describe()
# Out:
# count        31.000000
# mean      67634.225806
# std       28711.451492
# min       29071.000000
# 25%       43922.500000
# 50%       58366.000000
# 75%       85704.000000
# max      137264.000000
# Name: Population_size, dtype: float64

# %%
#showing distribution of population
sns.distplot(salmon['Population_size'])
plt.show()

# %%
#scatterplot of population
y=salmon.Population_size
x=salmon.Year
plt.scatter(x,y)
plt.xlabel('Year')
plt.ylabel('Salmon Population')
plt.title('Salmon Population 1984-2014')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))

# %%
#boxplot for Commercial Catch
salmon.boxplot(column='Commercial_catch')

#describe stats for Commercial Catch
salmon.Commercial_catch.describe()
# Out:
# count        31.000000
# mean     130182.516129
# std       61982.301144
# min       55701.000000
# 25%       88153.500000
# 50%      109827.000000
# 75%      134790.000000
# max      253888.000000
# Name: Commercial_catch, dtype: float64

# %%
#showing distribution of Commercial Catch
sns.distplot(salmon['Commercial_catch'])
plt.show()

# %%
#scatterplot of Commercial_catch
y=salmon.Commercial_catch
x=salmon.Year
plt.scatter(x,y)
plt.xlabel('Year')
plt.ylabel('Commercial Catch')
plt.title('Commercial Catch 1984-2014')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))

# %%
#boxplot for Recreation Catch
salmon.boxplot(column='Recreation_catch')

#describe stats for Recreation Catch
salmon.Recreation_catch.describe()
# Out:
# count        31.000000
# mean      64700.935484
# std       44126.668027
# min       22879.000000
# 25%       29544.000000
# 50%       44422.000000
# 75%       94149.500000
# max      173817.000000
# Name: Recreation_catch, dtype: float64

# %%
#showing distribution of Recreation Catch
sns.distplot(salmon['Recreation_catch'])
plt.show()

# %%
#scatterplot of Recreation_catch
y=salmon.Recreation_catch
x=salmon.Year
plt.scatter(x,y)
plt.xlabel('Year')
plt.ylabel('Recreational Catch')
plt.title('Recreational Catch 1984-2014')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))

# %%
#boxplot for Sea Lions
salmon.boxplot(column='Seal_pop')

#describe stats for Sea Lions
salmon['Seal_pop'].describe()
# Out:
# count        31.000000
# mean     185766.903226
# std       63175.121386
# min       93011.000000
# 25%      139541.000000
# 50%      191632.000000
# 75%      244262.000000
# max      306220.000000
# Name: Seal_pop, dtype: float64

# %%
#showing distribution of Sea Lions
sns.distplot(salmon['Seal_pop'])
plt.show()

# %%
#scatterplot of sea lions
y=salmon['Seal_pop']
x=salmon.Year
plt.scatter(x,y)
plt.xlabel('Year')
plt.ylabel('Sea Lion Population')
plt.title('Sea Lion Population 1984-2014')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))

# %%
#boxplot for Temperatures
salmon.boxplot(column='Temp')

#describe stats for Temperatures
salmon['Temp'].describe()
# Out:
# count    31.000000
# mean     53.535484
# std       0.886039
# min      51.440000
# 25%      53.015000
# 50%      53.470000
# 75%      54.230000
# max      55.260000
# Name: Temp, dtype: float64

# %%
#showing distribution of Temperatures
sns.distplot(salmon['Temp'])
plt.show()

# %%
#scatterplot of temperature
y=salmon.Temp
x=salmon.Year
plt.scatter(x,y)
plt.xlabel('Year')
plt.ylabel('Temperature')
plt.title('Temperatures 1984-2014')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#boxplot for Seattle
salmon.boxplot(column='Seattle_pop')

#describe stats for Seattle_pop
salmon['Seattle_pop'].describe()
# Out:
# count    3.100000e+01
# mean     2.614774e+06
# std      3.957333e+05
# min      1.940000e+06
# 25%      2.277500e+06
# 50%      2.669000e+06
# 75%      2.942000e+06
# max      3.220000e+06
# Name: Seattle_pop, dtype: float64

# %%
#showing distribution of Seattle_pop
sns.distplot(salmon['Seattle_pop'])
plt.show()

# %%
#scatterplot of Seattle_pop
y=salmon.Seattle_pop
x=salmon.Year
plt.scatter(x,y)
plt.xlabel('Year')
plt.ylabel('Seattle Population')
plt.title('Seattle Population 1984-2014')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#feature extraction to get overall catch data
salmon["Harvested"] = salmon["Commercial_catch"] + salmon["Recreation_catch"]
print(salmon)
# Out:
#     Year  Commercial_catch  Recreation_catch  Population_size   Temp  \
# 0   1984            241956            173817            87458  53.04
# 1   1985            245308            128042           113163  51.44
# 2   1986            223960            153426            98334  54.27
# 3   1987            213059            109374            86407  54.72
# 4   1988            231479            115300            94799  53.58
# 5   1989            253888            135696            85001  53.17
# 6   1990            250195            125504           137264  53.73
# 7   1991            141686             90566            57428  53.40
# 8   1992            109827             97733            42355  54.59
# 9   1993             81759             80166            33228  53.17
# 10  1994             86768             48286            41437  54.00
# 11  1995             80124             69799            51640  54.61
# 12  1996             76107             72069            58366  52.74
# ...

# %%
#feature selection - commercial catch and recreational are combined for total harvest amount

del salmon['Commercial_catch']
del salmon['Recreation_catch']

# %%
#checking to make sure commercial and recreation were dropped and new harvested column was added
salmon.head()
# Out:
#    Year  Population_size   Temp  Seal_pop  Seattle_pop  Harvested
# 0  1984            87458  53.04     93011      1940000     415773
# 1  1985           113163  51.44     93012      1982000     373350
# 2  1986            98334  54.27     96676      2025000     377386
# 3  1987            86407  54.72    101844      2069000     322433
# 4  1988            94799  53.58    106850      2114000     346779

# %%
#correlations between variables in the dataset
correlations=salmon.corr()
print(correlations)

import seaborn as sn
sn.heatmap(correlations, annot=True)
plt.figure(figsize=(100,50))
plt.show()
# Out:
#                      Year  Population_size      Temp  Seal_pop  Seattle_pop  \
# Year             1.000000        -0.536896 -0.016220  0.963883     0.997113
# Population_size -0.536896         1.000000 -0.139705 -0.547082    -0.517495
# Temp            -0.016220        -0.139705  1.000000 -0.142313    -0.015058
# Seal_pop         0.963883        -0.547082 -0.142313  1.000000     0.957770
# Seattle_pop      0.997113        -0.517495 -0.015058  0.957770     1.000000
# Harvested       -0.763214         0.596496 -0.149605 -0.706251    -0.796075
#
#                  Harvested
# Year             -0.763214
# Population_size   0.596496
# Temp             -0.149605
# Seal_pop         -0.706251
# Seattle_pop      -0.796075
# Harvested         1.000000

# %%
#harvested, our target variable, is very strongly correlated to seal pop and seattle pop
#population size is also strongly correlated
#temperature is not strongly correlated and isn't really useful

#feature extraction
#deleting temperature from dataset
del salmon['Temp']

# %%
#exporting as csv to use with r
salmon.to_csv('salmon.csv')

# %%
# Import Pandas Library, used for data manipulation
# Import matplotlib, used to plot our data
# Import numpy for linear algebra operations
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import our data
salmon=pd.read_csv('salmon.csv')

 
# Display the data 
salmon.head()
# Out:
#    Unnamed: 0  Year  Population_size  Seal_pop  Seattle_pop  Harvested
# 0           0  1984            87458     93011      1940000     415773
# 1           1  1985           113163     93012      1982000     373350
# 2           2  1986            98334     96676      2025000     377386
# 3           3  1987            86407    101844      2069000     322433
# 4           4  1988            94799    106850      2114000     346779

# %%
#POLYNOMIAL REGRESSION FOR SALMON POPULATION SIZE

# Import the function "PolynomialFeatures" from sklearn, to preprocess our data
# Import LinearRegression model from sklearn
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
# Set PolynomialFeatures to degree 2 and store in the variable pre_process
# Degree 2 preprocesses x to 1, x and x^2
# Degree 3 preprocesses x to 1, x, x^2 and x^3
# and so on..

#creating x/dependent variables
X=salmon[['Population_size']] #[[]] converts to 2D array

 
pre_process = PolynomialFeatures(degree=2)

# Transform our x input to 1, x and x^2

X_poly = pre_process.fit_transform(X)
# Show the transformation on the notebook
X_poly

#creating y/independent/target variable
y=salmon.Harvested

salmon_model = LinearRegression()

# Fit our preprocessed data to the polynomial regression model
salmon_model.fit(X_poly, y)

# Store our predicted harvest values in the variable y_new
y_pred = salmon_model.predict(X_poly)
# Plot our model on our data
plt.scatter(X, y, c = "black")
plt.xlabel("Salmon Population")
plt.ylabel("Harvest Amount")
plt.plot(X, y_pred)

# %%
#POLYNOMIAL REGRESSION FOR SEA LION POPULATION SIZE

# Import the function "PolynomialFeatures" from sklearn, to preprocess our data
# Import LinearRegression model from sklearn
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
# Set PolynomialFeatures to degree 2 and store in the variable pre_process
# Degree 2 preprocesses x to 1, x and x^2
# Degree 3 preprocesses x to 1, x, x^2 and x^3
# and so on..

#creating x/dependent variables
X=salmon[['Seal_pop']] #[[]] converts to 2D array

 
pre_process = PolynomialFeatures(degree=2)

# Transform our x input to 1, x and x^2

X_poly = pre_process.fit_transform(X)
# Show the transformation on the notebook
X_poly


# Transform our x input to 1, x and x^2

X_poly = pre_process.fit_transform(X)
# Show the transformation on the notebook
X_poly

#creating y/independent/target variable
y=salmon.Harvested

seal_model = LinearRegression()

# Fit our preprocessed data to the polynomial regression model
seal_model.fit(X_poly, y)

# Store our predicted Harvest values in the variable y_new
y_pred = seal_model.predict(X_poly)
# Plot our model on our data
plt.scatter(X, y, c = "black")
plt.xlabel("Sea Lion Population")
plt.ylabel("Harvest Amount")
plt.plot(X, y_pred)

# %%
#POLYNOMIAL REGRESSION FOR SEATTLE POPULATION SIZE

# Import the function "PolynomialFeatures" from sklearn, to preprocess our data
# Import LinearRegression model from sklearn
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
# Set PolynomialFeatures to degree 2 and store in the variable pre_process
# Degree 2 preprocesses x to 1, x and x^2
# Degree 3 preprocesses x to 1, x, x^2 and x^3
# and so on..

#creating x/dependent variables
X=salmon[['Seattle_pop']] #[[]] converts to 2D array

 
pre_process = PolynomialFeatures(degree=2)

# Transform our x input to 1, x and x^2

X_poly = pre_process.fit_transform(X)
# Show the transformation on the notebook
X_poly


# Transform our x input to 1, x and x^2

X_poly = pre_process.fit_transform(X)
# Show the transformation on the notebook
X_poly

#creating y/independent/target variable
y=salmon.Harvested

seattle_model = LinearRegression()

# Fit our preprocessed data to the polynomial regression model
seattle_model.fit(X_poly, y)

# Store our predicted Harvest values in the variable y_new
y_pred = seattle_model.predict(X_poly)
# Plot our model on our data
plt.scatter(X, y, c = "black")
plt.xlabel("Seattle Population")
plt.ylabel("Harvest Amount")
plt.plot(X, y_pred)

# %%
#USER INPUT PROMPT FOR DEPLOYMENT
import requests


var=input('Which variable would you like to input data for? Please type "Sea Lion" or "Seattle".\n')
val=input("Please enter a data value.\n")

if var=="Sea Lion":
    y_new=seal_model.predict(pre_process.fit_transform([[int(val)]]))
    print("The predicted harvest size based on this Sea Lion population size is: \n",y_new)
    
if var=='Seattle':
    y_new=seattle_model.predict(pre_process.fit_transform([[int(val)]]))
    print("The predicted harvest size based on this Seattle population size is: \n",y_new)
